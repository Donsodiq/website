# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = "/Users/OmoAjady/Desktop/hamoye/fao.csv"

# %%
fao = pd.read_csv(df)
fao.head()
# Out:
#    Area Code     Area  Item Code         Item  Element Code  \
# 0          4  Algeria       2501   Population           511
# 1          4  Algeria       2501   Population          5301
# 2          4  Algeria       2901  Grand Total           664
# 3          4  Algeria       2901  Grand Total           674
# 4          4  Algeria       2901  Grand Total           684
#
#                                   Element             Unit     Y2014  \
# 0           Total Population - Both sexes     1000 persons  38924.00
# 1                Domestic supply quantity      1000 tonnes      0.00
# 2           Food supply (kcal/capita/day)  kcal/capita/day   3377.00
# 3  Protein supply quantity (g/capita/day)     g/capita/day     94.90
# 4      Fat supply quantity (g/capita/day)     g/capita/day     80.06
#
#       Y2015     Y2016     Y2017     Y2018
# 0  39728.00  40551.00  41389.00  42228.00
# 1      0.00      0.00      0.00      0.00
# 2   3379.00   3372.00   3341.00   3322.00
# ...

# %%
fao.shape
# Out:
# (60943, 12)

# %%
fao.describe()
# Out:
#           Area Code     Item Code  Element Code          Y2014          Y2015  \
# count  60943.000000  60943.000000  60943.000000   59354.000000   59395.000000
# mean     134.265576   2687.176706   3814.856456     134.196282     135.235966
# std       72.605709    146.055739   2212.007033    1567.663696    1603.403984
# min        4.000000   2501.000000    511.000000   -1796.000000   -3161.000000
# 25%       74.000000   2562.000000    684.000000       0.000000       0.000000
# 50%      136.000000   2630.000000   5142.000000       0.090000       0.080000
# 75%      195.000000   2775.000000   5511.000000       8.340000       8.460000
# max      276.000000   2961.000000   5911.000000  176405.000000  181137.000000
#
#                Y2016          Y2017          Y2018
# count   59408.000000   59437.000000   59507.000000
# mean      136.555222     140.917765     143.758381
# std      1640.007194    1671.862359    1710.782658
# min     -3225.000000   -1582.000000   -3396.000000
# ...

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60943 entries, 0 to 60942
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Area Code     60943 non-null  int64
#  1   Area          60943 non-null  object
#  2   Item Code     60943 non-null  int64
#  3   Item          60943 non-null  object
#  4   Element Code  60943 non-null  int64
#  5   Element       60943 non-null  object
#  6   Unit          60943 non-null  object
#  7   Y2014         59354 non-null  float64
#  8   Y2015         59395 non-null  float64
#  9   Y2016         59408 non-null  float64
#  10  Y2017         59437 non-null  float64
#  11  Y2018         59507 non-null  float64
# dtypes: float64(5), int64(3), object(4)
# memory usage: 5.6+ MB

# %%
fao.head(100)
# Out:
#     Area Code     Area  Item Code              Item  Element Code  \
# 0           4  Algeria       2501        Population           511
# 1           4  Algeria       2501        Population          5301
# 2           4  Algeria       2901       Grand Total           664
# 3           4  Algeria       2901       Grand Total           674
# 4           4  Algeria       2901       Grand Total           684
# ..        ...      ...        ...               ...           ...
# 95          4  Algeria       2515  Rye and products           674
# 96          4  Algeria       2515  Rye and products           684
# 97          4  Algeria       2516              Oats          5511
# 98          4  Algeria       2516              Oats          5611
# 99          4  Algeria       2516              Oats          5072
#
#                                    Element             Unit     Y2014  \
# 0            Total Population - Both sexes     1000 persons  38924.00
# ...

# %%
fao.notnull().sum()
# Out:
# Area Code       60943
# Area            60943
# Item Code       60943
# Item            60943
# Element Code    60943
# Element         60943
# Unit            60943
# Y2014           59354
# Y2015           59395
# Y2016           59408
# Y2017           59437
# Y2018           59507
# dtype: int64

# %%
fao.isnull().sum()
# Out:
# Area Code          0
# Area               0
# Item Code          0
# Item               0
# Element Code       0
# Element            0
# Unit               0
# Y2014           1589
# Y2015           1548
# Y2016           1535
# Y2017           1506
# Y2018           1436
# dtype: int64

# %%
#mean in 2015
fao["Y2015"].mean()
# Out:
# 135.23596649549236

# %%
#standar deviation in 2015
fao["Y2015"].std()
# Out:
# 1603.4039839423301

# %%
#total number in 2016
fao_2016 = fao["Y2016"].isnull().sum()
fao_2016
# Out:
# 1535

# %%
df_2016 = fao["Y2016"].count()
df_2016
# Out:
# 59408

# %%
#percentage of missing number
df1 = (fao_2016/df_2016) * 100
df1
# Out:
# 2.583827093994075

# %%
fao["Element Code"].max()
# Out:
# 5911

# %%
fao["Y2016"].max()
# Out:
# 185960.0

# %%
fao["Y2015"].max()
# Out:
# 181137.0

# %%
fao["Y2014"].max()
# Out:
# 176405.0

# %%
fao["Y2018"].max()
# Out:
# 195875.0

# %%
fao.corr
# Out:
# <bound method DataFrame.corr of        Area Code      Area  Item Code           Item  Element Code  \
# 0              4   Algeria       2501     Population           511
# 1              4   Algeria       2501     Population          5301
# 2              4   Algeria       2901    Grand Total           664
# 3              4   Algeria       2901    Grand Total           674
# 4              4   Algeria       2901    Grand Total           684
# ...          ...       ...        ...            ...           ...
# 60938        181  Zimbabwe       2899  Miscellaneous          5142
# 60939        181  Zimbabwe       2899  Miscellaneous           645
# 60940        181  Zimbabwe       2899  Miscellaneous           664
# 60941        181  Zimbabwe       2899  Miscellaneous           674
# 60942        181  Zimbabwe       2899  Miscellaneous           684
#
#                                       Element             Unit     Y2014  \
# ...

# %%
df1 = fao.groupby("Element").max()
df1
# Out:
#                                         Area Code                   Area  \
# Element
# Domestic supply quantity                      276               Zimbabwe
# Export Quantity                               276               Zimbabwe
# Fat supply quantity (g/capita/day)            276               Zimbabwe
# Feed                                          276               Zimbabwe
# Food                                          276               Zimbabwe
# Food supply (kcal/capita/day)                 276               Zimbabwe
# Food supply quantity (kg/capita/yr)           276               Zimbabwe
# Import Quantity                               276               Zimbabwe
# Losses                                        276               Zimbabwe
# Other uses (non-food)                         276               Zimbabwe
# Processing                                    276               Zimbabwe
# Production                                    276               Zimbabwe
# ...

# %%
df2 = fao.groupby("Element").sum()
df2["Y2014"].sum()
# Out:
# 7965086.130000004

# %%
df1 = fao.groupby("Element").sum()
df1
# Out:
#                                         Area Code  Item Code  Element Code  \
# Element
# Domestic supply quantity                   708993   14197445      28068795
# Export Quantity                            599910   11840553      26026133
# Fat supply quantity (g/capita/day)         675050   13535000       3435732
# Feed                                       176272    3538507       7282199
# Food                                       663295   13285035      25406622
# Food supply (kcal/capita/day)              674057   13511060       3329296
# Food supply quantity (kg/capita/yr)        658446   13185401       3163725
# Import Quantity                            688174   13795966      28834929
# Losses                                     274353    5424803      10292107
# Other uses (non-food)                      235554    4729749       8926728
# Processing                                 271940    5350416      10313310
# ...

# %%
fao
